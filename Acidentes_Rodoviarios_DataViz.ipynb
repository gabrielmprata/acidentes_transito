# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielmprata/acidentes_transito/blob/main/Acidentes_Rodoviarios_DataViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img loading="lazy" src="https://cdn.jsdelivr.net/gh/devicons/devicon@latest/icons/python/python-original.svg" width="40" height="40"/> <img src="https://cdn.jsdelivr.net/gh/devicons/devicon@latest/icons/pandas/pandas-original-wordmark.svg" width="40" height="40"/>   <img loading="lazy" src="https://cdn.jsdelivr.net/gh/devicons/devicon@latest/icons/plotly/plotly-original-wordmark.svg" width="40" height="40"/>  <img loading="lazy" src="https://cdn.jsdelivr.net/gh/devicons/devicon@latest/icons/streamlit/streamlit-original-wordmark.svg" width="40" height="40"/>
#
# ---
# >
# **Dev**: Gabriel Prata
# >
# **Data**: 07/03/2025
# >
# **Última modificação**: 07/03/2025
# >
# ---

# %% [markdown]
# ![Badge em Desenvolvimento](http://img.shields.io/static/v1?label=STATUS&message=EM%20DESENVOLVIMENTO&color=GREEN&style=for-the-badge)
#
# ![Badge versao](http://img.shields.io/static/v1?label=Ver.&message=v1.0&color=red&style=for-the-badge&logo=github)
#
#
# ---

# %% [markdown]
# #**<font color=#4c60d6 size="6"> 1. Import libraries**

# %%
# Importação de pacotes
import pandas as pd
import numpy as np

#bibliotecas para visualização de dados
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# Configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #**<font color=#4c60d6 size="6"> 2. Carga dos dados**

# %% [markdown]
# Carga do arquivo pre-processado gerado no notebook:
# >
# [<img loading="lazy" src="https://cdn.jsdelivr.net/gh/devicons/devicon@latest/icons/github/github-original-wordmark.svg" width="40" height="40"/>](https://github.com/gabrielmprata/acidentes_transito/blob/main/Acidentes_Rodoviarios_PreProc.ipynb)
# [<img src="https://img.shields.io/badge/Colab-F9AB00?style=for-the-badge&logo=googlecolab&color=525252"/>](https://colab.research.google.com/drive/1nDM1CrBBSWPYoYYTc2vmpkQaDJ3pLu-K)

# %%
# importando dataset

# URL de importação
url   = "https://raw.githubusercontent.com/gabrielmprata/acidentes_transito/main/datasets/df_acidentes_2024.csv.bz2"

url2   = "https://raw.githubusercontent.com/gabrielmprata/acidentes_transito/main/datasets/df_hs_acidentes.csv.bz2"

df_acidentes = pd.read_csv(url, compression='bz2', encoding = "utf8", delimiter=',')

# Ano atual com 2023 somente para comparativo
df_acidentes_2023 = pd.read_csv(url2, compression='bz2', encoding = "Latin 1", delimiter=',')

# %%
df_acidentes
# Out:
#              id data_inversa     dia_semana   horario  uf   br     km  \
# 0      571789.0   2024-01-01  segunda-feira  03:56:00  ES  101     38
# 1      571804.0   2024-01-01  segunda-feira  04:50:00  PI  343    185
# 2      571806.0   2024-01-01  segunda-feira  04:30:00  BA  116    578
# 3      571818.0   2024-01-01  segunda-feira  06:30:00  SE  101     18
# 4      571838.0   2024-01-01  segunda-feira  05:00:00  MT  364    240
# ...         ...          ...            ...       ...  ..  ...    ...
# 73151  661295.0   2024-12-21         sábado  07:00:00  PB  230  135,2
# 73152  661307.0   2024-12-01        domingo  06:30:00  RJ  393    298
# 73153  661377.0   2024-07-09    terça-feira  16:20:00  ES  101  101,5
# 73154  661576.0   2024-12-17    terça-feira  21:35:00  RJ  101    391
# 73155  661598.0   2024-12-27    sexta-feira  13:00:00  ES  101     67
#
#                 municipio                                     causa_acidente  \
# 0      CONCEICAO DA BARRA                             Ultrapassagem Indevida
# 1                PIRIPIRI                        Manobra de mudança de faixa
# 2                 BREJOES                   Ingestão de álcool pelo condutor
# 3        MALHADA DOS BOIS           Reação tardia ou ineficiente do condutor
# 4            RONDONOPOLIS  Condutor deixou de manter distância do veículo...
# ...                   ...                                                ...
# 73151      CAMPINA GRANDE                     Ausência de reação do condutor
# 73152       VOLTA REDONDA                     Ausência de reação do condutor
# 73153           SOORETAMA           Desrespeitar a preferência no cruzamento
# 73154      RIO DE JANEIRO                                  Frear bruscamente
# 73155          SAO MATEUS                                 Conversão proibida
#
#                         tipo_acidente  ...  longitude            data_hora  \
# 0      Colisão lateral sentido oposto  ... -39.923790  2024-01-01 03:56:00
# 1                     Colisão frontal  ... -41.767327  2024-01-01 04:50:00
# 2                     Colisão frontal  ... -39.961111  2024-01-01 04:30:00
# 3           Saída de leito carroçável  ... -36.905522  2024-01-01 06:30:00
# 4                    Colisão traseira  ... -54.789053  2024-01-01 05:00:00
# ...                               ...  ...        ...                  ...
# 73151       Saída de leito carroçável  ... -35.768394  2024-12-21 07:00:00
# 73152                 Colisão frontal  ... -44.112986  2024-12-01 06:30:00
# 73153             Colisão transversal  ... -39.999335  2024-07-09 16:20:00
# 73154                Colisão traseira  ... -43.684920  2024-12-17 21:35:00
# 73155             Colisão transversal  ... -39.865893  2024-12-27 13:00:00
#
#         ano mes hora  ano_mes semana  sinistro         uf_nome        regiao
# 0      2024   1    3  2024-01      0         1  Espírito Santo       Sudeste
# 1      2024   1    4  2024-01      0         1           Piauí      Nordeste
# 2      2024   1    4  2024-01      0         1           Bahia      Nordeste
# 3      2024   1    6  2024-01      0         1         Sergipe      Nordeste
# 4      2024   1    5  2024-01      0         1     Mato Grosso  Centro-Oeste
# ...     ...  ..  ...      ...    ...       ...             ...           ...
# 73151  2024  12    7  2024-12      5         1         Paraíba      Nordeste
# 73152  2024  12    6  2024-12      6         1  Rio de Janeiro       Sudeste
# 73153  2024   7   16  2024-07      1         1  Espírito Santo       Sudeste
# 73154  2024  12   21  2024-12      1         1  Rio de Janeiro       Sudeste
# 73155  2024  12   13  2024-12      4         1  Espírito Santo       Sudeste
#
# [73156 rows x 36 columns]
